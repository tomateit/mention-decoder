# %% [markdown]
# https://habr.com/ru/post/564916/

# %%
from pathlib import Path
from custom_types import Sample
from locate_spans import locate_spans
from custom_datasets import IterableJsonDataset
from tqdm import tqdm

# %%
data_dir = Path("./data/news_org/")

# %%
import torch
from transformers import FSMTModel, FSMTTokenizer, FSMTForConditionalGeneration

# %%
tokenizer = FSMTTokenizer.from_pretrained("facebook/wmt19-en-ru")
model = FSMTForConditionalGeneration.from_pretrained("facebook/wmt19-en-ru")

inverse_tokenizer = FSMTTokenizer.from_pretrained("facebook/wmt19-ru-en")
inverse_model = FSMTForConditionalGeneration.from_pretrained("facebook/wmt19-ru-en")

# %%
model.cuda();
inverse_model.cuda();

# %%
def paraphrase(samples: list[Sample], gram=4, num_beams=5, **kwargs):
    """ Generate a paraphrase using back translation. 
    Parameter `gram` denotes size of token n-grams of the original sentence that cannot appear in the paraphrase.
    """
    # Encoding
    texts = [s.text for s in samples]
    input_ids = inverse_tokenizer.batch_encode(texts, return_tensors="pt")
    
    with torch.no_grad():
        outputs = inverse_model.generate(input_ids.to(inverse_model.device), num_beams=num_beams, **kwargs)
    # Translated
    other_lang = inverse_tokenizer.batch_decode(outputs, skip_special_tokens=True)
    # print(other_lang)
    
    # Bad ids calculation
    input_ids = input_ids[0, :-1].tolist()
    bad_word_ids = [input_ids[i:(i+gram)] for i in range(len(input_ids)-gram)]
    
    # Backtranslation
    input_ids = tokenizer.encode(other_lang, return_tensors="pt")
    with torch.no_grad():
        # Constrained back translation shall be in a loop
        # bc cannot use force ids with batches
        outputs = model.generate(input_ids.to(model.device), num_beams=num_beams, bad_words_ids=bad_word_ids, **kwargs)
    
    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded

# %%
dataset = IterableJsonDataset(data_dir)

# %%
total = 0
for _ in IterableJsonDataset(data_dir):
    total+=1
total
# Out:
# 136171

# %%
from torch.nn.functional import pad

# %%
pad(output, (0, 250 - output.shape[1]), value=tokenizer.pad_token_id).shape
# Out:
# torch.Size([1, 250])

# %%
data_iterator = iter(dataset)
batch_size = 8
num_beams=5
gram=4
for i in tqdm(range(total)):
    batch = []

    # Not all entities are good
    while len(batch) != batch_size:
        sample = next(data_iterator)
        if len(sample.ent) < 3:
            continue
        if len(inverse_tokenizer(sample.text, truncation=False)["input_ids"]) > 200:
            continue

        batch.append(sample)
    # ---------------------
    samples = batch
    
    # Encoding
    texts = [s.text for s in samples]
    encoded_input = inverse_tokenizer(texts, return_tensors="pt", max_length=200, padding=True, truncation=True)
    decoded_input = [tokenizer.batch_decode(x) for x in encoded_input["input_ids"]]
    # Align tokens with entity span
    entity_spans = locate_spans(decoded_input, samples)
    
    
    with torch.no_grad():
        inputs = encoded_input["input_ids"].to(inverse_model.device)
        
        outputs = inverse_model.generate(inputs=inputs, num_beams=num_beams, max_new_tokens=250)
    
    
    # Translated
    other_lang = inverse_tokenizer.batch_decode(outputs, skip_special_tokens=True)
    # print(other_lang)
    

    # Good ids calculation
    force_words_ids = []
    for inp, span in zip(inputs, entity_spans):
        entity_tokens = inp[span[0]:span[1]+1].tolist()
        force_words_ids.append(entity_tokens)
    
    # Bad ids calculation
    bad_word_ids = []
    for text, good_ids in zip(texts, force_words_ids):
        input_ids = inverse_tokenizer.encode(text)
        candidates = [input_ids[i:(i+gram)] for i in range(len(input_ids)-gram)]
        # TODO check intersection with force_words_ids
        bad_word_ids.append(candidates)

    
    # Backtranslation
    input_ids = tokenizer(other_lang, return_tensors="pt", max_length=250, padding=True, truncation=True)
    with torch.no_grad():
        # Constrained back translation shall be in a loop
        # bc cannot use force ids with batches
        inputs = input_ids.to(model.device)
        outputs = []
        for inp, atm, force_words_id, bad_word_id in zip(inputs["input_ids"], inputs["attention_mask"], force_words_ids, bad_word_ids):
            inp = inp.unsqueeze(0)
            output = model.generate(
                inputs=inp,
                num_beams=num_beams, 
                bad_words_ids=bad_word_id,
                force_words_ids=[force_words_id],
                repetition_penalty=3.14,
            )
            output = pad(output, (0, 250 - output.shape[1]), value=tokenizer.pad_token_id)
            outputs.append(output)
    
    outputs = torch.concat(outputs)
    decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    # return decoded
    break
    # ---------------------
# Out:
#   0%|                                                                                                                                 | 0/136171 [00:00<?, ?it/s]/home/max/code/research_mention_decoder/.venv/lib/python3.10/site-packages/transformers/generation_utils.py:1202: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 200 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#   0%|                                                                                                                                 | 0/136171 [01:29<?, ?it/s]

# %%
for sp, d in zip(samples, decoded):
    print(sp.text)
    print(d)
    print("-----------")
# Out:
# На прошлой неделе министр энергетики Белоруссии Виктор Каранкевич сообщил, что Минск намерен возобновить газовые переговоры с Москвой до конца января.О ходе переговоров Минска и Москвы на поставку сырья в 2020 году — в материале “Ъ” «Нефти контракты не писаны».О резком сокращении поставок российского газа — в материале “Ъ” «"Газпром" снижает экспорт в Европу».
# О ходе переговоров между Минском и Москвой по поставкам сырья на 2020 год - в материале Ъ "Нефтяные контракты не пишутся", о резком снижении поставок газа из России - в материале Ъ "Газпром" наращивает экспорт в Европу.
# -----------
# Белоруссия закупила 80 тыс. тонн норвежской нефти, сообщил представитель госконцерна «Белнефтехим».
# "Беларус" закупил 80 тыс. тонн нефти, сообщил журналистам представитель госконБелнефтехима. В настоящее время компания закупает около 20 тыс. тонн нефти в год. По его словам, объем поставок составляет примерно $100 млн. Это на 30% больше, чем в прошлом году. На сегодняшний день поставки составляют более 10 млн тонн нефти в год. Но это не означает, что белорусская нефть будет поставляться по трубопроводу через Белоруссию. Как отметил представитель концерна, Белоруссия уже приобрела у России 80,000 тонн нефти. (далее...) - Беларусь купила у Белоруссии 800 тыс. тонн нефти для экспорта через Белоруссию и Казахстан. [подробнее...] Белоруснефть покупает у Беларуси 80 тыс. тонн нефти из Китая, сказал представитель государственного концерна "Белнефтехим". & # 160; Белнефтехимнефть & # 160; рассказал представитель Белнефтехимик. Он также заявил, что Россия может купить у Белоруссии 80 тыс. тонн нефти за Белнефтехим
# -----------
# Тем самым был поставлен крест на проекте «Печора СПГ», который мог стать первым СПГ-заводом «Роснефти», без этих месторождений оказалось невозможно сформировать достаточную ресурсную базу для завода.
# Это положило конец проекту "Печоры СПГ" - первому заводу "Роснефти" по сжижению природного газа (СПГ), без которого невозможно было сформировать достаточную для завода ресурсную базу.
# -----------
# Но пока, отмечает партнер KPMG в России и СНГ Виктория Тургенева, участок достаточно мало изучен, о нем немного доступной информации.
# Но пока, замечает партнер КПМГ в России и странах СНГ Виолетта Тургеневая, сайт недостаточно изучен и информации о нем мало KPMG.
# -----------
# Но, отмечает заместитель главы ФНЭБ Алексей Гривач, Сопочный участок находится рядом с перспективными участками монополии в районе Обской и Тазовской губ.
# Но, отмечает замруководителя Фонда национальной экономической безопасности Алексей Гривача, площадка "Сопчий" расположена рядом с перспективным монопольным участком в районе обской и тазовской губы. В частности, на участке площадью около 100 га расположены два завода по производству полипропилена - "Красный Октябрь" и "Агропром". По словам Гривача, сейчас там сосредоточено более 30% всех мощностей по переработке полипропилена. Он также отметил, что компания работает над созданием нового производства полипропилена для переработки отходов. На данный момент ведутся переговоры о его создании с несколькими крупными производителями из России: компанией "Роснано", а также с компаниями "Русские машины" и "Автодор". Кроме того, планируется построить завод по производству полипропилена в городе Подолье (Москва). Как ожидается, проект будет реализован до конца текущего года. Однако, как сообщил он, пока не определено, сколько именно ФНЭБ
# -----------
# Сам «Газпром» оценивал ресурсный потенциал более чем в 500 млн тонн условного топлива.
# В самом "Газпроме" ресурсный потенциал оценили более чем на 500 млн т условного топлива (БТТ), что соответствует заявленным объемам добычи. По данным компании, в прошлом году было добыто около 1 млрд куб. м нефти и газа, а к 2020 году - уже 2 млрд куб. м угля и 15 млрд куб. м природного газа. Но эксперты считают, что запасы могут быть увеличены до 3 трлн куб. м с нынешних 4 трлн куб. м. При этом объем экспорта может превысить 5 трлн куб. м или даже 10 трлн куб. м нефтяного эквивалента по сравнению с 1,5 трлн куб. м в 2010 году. И это при том, что экспорт составляет всего лишь 30% от ВВП страны. На сегодняшний день Россия является крупнейшим поставщиком сжиженного природного газа в мире: его доля в общем объеме поставок российского газа оценивается примерно в 100 млрд куб. м / год. Однако Газпром оценивает этот потенциал как минимум в 500 млрд куб. м эталонного топлива.
# -----------
# «Газпром», редкий участник аукционов на лицензионные участки, в конце 2019 года заплатил более 12 млрд руб. за Сопочный участок на Ямале с ресурсами 260 млрд кубометров газа.
# "Газпром" - редкий претендент на лицензионный участок в Ямало-Ненецком автономном округе (ЯНАО) - заплатил за Сопкинский участок с запасами газа более 12 млрд куб. м к концу 2019 года.
# -----------
# Подробности — в публикации “Ъ” «"Дружба" потребовала ремонта».О переговорах России и Белоруссии об условиях прокачки российской нефти — в материале “Ъ”.
# Подробнее о переговорах России с Белоруссией по условиям поставок российской нефти читайте в материале "Коммерсанта" "дружба" потребовалась на ремонт. Дружба требовала ремонта ". О переговорах между Россией и Беларусью по условиям поставок российской нефти читайте в материале" КоммерсантЪ "" Российско-белорусские отношения нуждаются в ремонте ".
# -----------

# %%
for o in outputs:
    print(o.shape)
output.shape
# Out:
# torch.Size([1, 33])
# torch.Size([1, 33])

# %%
torch.concat(outputs).shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 torch.concat(outputs).shape
#
# RuntimeError: Sizes of tensors must match except in dimension 0. Expected size 50 but got size 34 for tensor number 1 in the list.

# %%
tokenizer.batch_decode(outputs[0], skip_special_tokens=True)
# Out:
# ['Глава международного отдела Hyundai Йоланда Лэй отмечает, что компания отправила антисептики и инсектициды пострадавшим в Ханчжоу, но она ожидает, что государственные власти Китая держат ситуацию на контроле.']

# %%
for sample, bwi in zip(samples, bad_word_ids):
    print(sample.text)
    for bw in bwi:
        print(tokenizer.decode(bw))
# Out:
# Пока это только пилотный проект, его тестируют в закрытом режиме на покупателях магазина «Азбука вкуса» в деловом центре «Москва-Сити».
# Пока это только пило
# это только пилотный
# только пилотный проект
# пилотный проект,
# тный проект, его
# проект, его тести
# , его тестируют
# его тестируют в
# тестируют в закры
# руют в закрытом
# в закрытом режиме
# закрытом режиме на
# том режиме на покупа
# режиме на покупателях
# на покупателях магазина
# покупателях магазина "
# телях магазина "А
# магазина "Аз
# "Азбу
# Азбука
# збука вку
# бука вкуса
# ка вкуса "
# вкуса "в
# са "в дело
# "в деловом
# в деловом центре
# деловом центре "
# вом центре "Москва
# центре "Москва-
# "Москва-Сити
# Москва-Сити "
# -Сити ".
# Возможность отказаться от писем есть и сейчас: сервис «Почты России» zakaznoe.pochta.ru позволяет гражданам при желании получать юридически значимые документы исключительно в электронном виде.
# Возможность отказаться от
# ность отказаться от писем
# отказаться от писем есть
# от писем есть и
# писем есть и сейчас
# есть и сейчас:
# и сейчас: сервис
# сейчас: сервис "
# : сервис "Поч
# сервис "Почты
# "Почты России
# Почты России "
# ты России "z
# России "zak
# "zakaz
# zakazno
# akaznoe.
# aznoe.p
# noe.poc
# e.pocht
# pochta.ru
# ochta.ru позволяет
# hta.ru позволяет гражданам
# a.ru позволяет гражданам при
# позволяет гражданам при желании
# гражданам при желании получать
# при желании получать юридически
# желании получать юридически значи
# получать юридически значимые
# юридически значимые документы
# значимые документы исключительно
# мые документы исключительно в
# документы исключительно в электро
# исключительно в электронном
# в электронном виде
# электронном виде.
# Ну и затраты органов власти на доставку великиПо данным Минкомсвязи, в 2019 году гражданам направлено почти 600 млн уведомлений, включая оповещения о штрафах и пенях, госбюджету такой объем обходится в 22 млрд руб. ежегодно.
# Ну и затраты органов
# и затраты органов власти
# затраты органов власти на
# органов власти на до
# власти на доставку
# на доставку вели
# доставку велики
# ставку великиПо
# великиПо данным
# киПо данным Мин
# По данным Минком
# данным Минкомсвязи
# Минкомсвязи,
# комсвязи, в
# связи, в 2019
# , в 2019 году
# в 2019 году гражданам
# 2019 году гражданам направлено
# году гражданам направлено почти
# гражданам направлено почти 600
# направлено почти 600 млн
# почти 600 млн уведо
# 600 млн уведомл
# млн уведомлений
# уведомлений,
# млений, включая
# ений, включая опове
# , включая оповещения
# включая оповещения о
# оповещения о штра
# щения о штрафа
# о штрафах
# штрафах и
# фах и пен
# х и пенях
# и пенях,
# пенях, гос
# ях, госбюджету
# , госбюджету такой
# госбюджету такой объем
# бюджету такой объем обходи
# такой объем обходится
# объем обходится в
# обходится в 22
# тся в 22 млрд
# в 22 млрд руб.
# 22 млрд руб. ежегодно
# млрд руб. ежегодно.
# Например, если гражданин подал заявление на получение социальной выплаты, он получит электронные уведомления о ходе и результатах рассмотрения на портале госуслуг или через мобильное приложение, указывают в Минкомсвязи.
# Например, если гражданин
# , если гражданин подал
# если гражданин подал заявление
# гражданин подал заявление на
# подал заявление на получение
# заявление на получение социальной
# на получение социальной выплаты
# получение социальной выплаты,
# социальной выплаты, он
# выплаты, он получит
# , он получит электронные
# он получит электронные уведомления
# получит электронные уведомления о
# электронные уведомления о ходе
# уведомления о ходе и
# о ходе и результатах
# ходе и результатах рассмотрения
# и результатах рассмотрения на
# результатах рассмотрения на портале
# рассмотрения на портале госу
# на портале госуслу
# портале госуслуг
# госуслуг или
# слуг или через
# г или через моби
# или через мобильное
# через мобильное приложение
# мобильное приложение,
# льное приложение, указывают
# приложение, указывают в
# , указывают в Мин
# указывают в Минком
# в Минкомсвязи
# Минкомсвязи.
# Минкомсвязь подготовила законопроект о переводе в электронный формат всех уведомлений от государства гражданам и организациям, например, о начисленных штрафах и пенях.
# Минкомсвязь подгото
# комсвязь подготовила
# связь подготовила законопроект
# подготовила законопроект о
# вила законопроект о переводе
# законопроект о переводе в
# о переводе в электро
# переводе в электронный
# в электронный формат
# электронный формат всех
# нный формат всех уведо
# формат всех уведомл
# всех уведомлений
# уведомлений от
# млений от государства
# ений от государства гражданам
# от государства гражданам и
# государства гражданам и организациям
# гражданам и организациям,
# и организациям, например
# организациям, например,
# , например, о
# например, о начислен
# , о начисленных
# о начисленных штра
# начисленных штрафа
# ных штрафах
# штрафах и
# фах и пен
# х и пенях
# и пенях.
# Вечной блокировке в России, напоминает она, подвергаются только ресурсы, которые сами стали нарушителями, как, например, LinkedIn, отказавшаяся хранить персональные данные россиян на территории РФ, или те, где пиратские книги и фильмы распространяются систематически.Валерия Лебедева
# Вечной блокировке
# чной блокировке в
# блокировке в России
# ровке в России,
# в России, напоминает
# России, напоминает она
# , напоминает она,
# напоминает она, подвергаются
# она, подвергаются только
# , подвергаются только ресурсы
# подвергаются только ресурсы,
# только ресурсы, которые
# ресурсы, которые сами
# , которые сами стали
# которые сами стали наруши
# сами стали нарушителями
# стали нарушителями,
# нарушителями, как
# телями, как,
# , как, например
# как, например,
# , например, Lin
# например, Link
# , Linked
# LinkedIn
# kedIn,
# edIn, отказа
# In, отказавшаяся
# , отказавшаяся хранить
# отказавшаяся хранить персона
# вшаяся хранить персональные
# хранить персональные данные
# персональные данные россиян
# льные данные россиян на
# данные россиян на территории
# россиян на территории РФ
# на территории РФ,
# территории РФ, или
# РФ, или те
# , или те,
# или те, где
# те, где пира
# , где пиратские
# где пиратские книги
# пиратские книги и
# тские книги и фильмы
# книги и фильмы распространяются
# и фильмы распространяются систематиче
# фильмы распространяются систематически
# распространяются систематически.
# систематически.Валерия
# ски.Валерия Лебедева
# Google уклоняется от исполнения решения, контент по-прежнему не удален, а блокировка конкретной страницы «не приведет к желаемому результату, появляются новые видео», говорит госпожа Симоненко.
# Google уклоняется от
# уклоняется от исполнения
# няется от исполнения решения
# от исполнения решения,
# исполнения решения, контен
# решения, контент
# , контент по
# контент по-
# т по-прежнему
# по-прежнему не
# -прежнему не уда
# прежнему не удален
# не удален,
# удален, а
# лен, а блоки
# , а блокировка
# а блокировка конкретной
# блокировка конкретной страницы
# ровка конкретной страницы "
# конкретной страницы "не
# страницы "не приведет
# "не приведет к
# не приведет к жела
# приведет к желаемому
# к желаемому результа
# желаемому результату
# емому результату,
# результату, появляются
# ту, появляются новые
# , появляются новые видео
# появляются новые видео "
# новые видео ",
# видео ", говорит
# ", говорит госпожа
# , говорит госпожа Симо
# говорит госпожа Симоненко
# госпожа Симоненко.
# Все рекомендации Роспотребнадзора и иных органов учтены: в комплексе нет сложностей с соблюдением социальной дистанции, у каждого входа размещены санитайзеры, посетителям будут бесплатно раздаваться маски и перчатки, а персонал ежедневно проходит медицинский контроль, заявили там.Александра Мерцалова, Никита Щуренков, Анатолий Костырев
# Все рекомендации Роспотребнадзора и
# рекомендации Роспотребнадзора и иных
# Роспотребнадзора и иных органов
# и иных органов учтены
# иных органов учтены:
# органов учтены: в
# учтены: в комплексе
# : в комплексе нет
# в комплексе нет слож
# комплексе нет сложностей
# нет сложностей с
# сложностей с соблюдением
# ностей с соблюдением социальной
# с соблюдением социальной дистанции
# соблюдением социальной дистанции,
# социальной дистанции, у
# дистанции, у каждого
# , у каждого входа
# у каждого входа размещены
# каждого входа размещены сани
# входа размещены санитай
# размещены санитайзер
# санитайзеры
# тайзеры,
# зеры, посети
# ы, посетителям
# , посетителям будут
# посетителям будут бесплатно
# телям будут бесплатно разда
# будут бесплатно раздаваться
# бесплатно раздаваться ма
# раздаваться маски
# ваться маски и
# маски и пер
# ски и перча
# и перчатки
# перчатки,
# чатки, а
# тки, а персонал
# , а персонал ежедневно
# а персонал ежедневно проходит
# персонал ежедневно проходит медицин
# ежедневно проходит медицинский
# проходит медицинский контроль
# медицинский контроль,
# ский контроль, заявили
# контроль, заявили та
# , заявили там
# заявили там.
# там.Александра
# м.Александра Мер
# .Александра Мерца
# Александра Мерцалова
# Мерцалова,
# цалова, Никита
# лова, Никита Щ
# , Никита Щур
# Никита Щурен
# Щуренков
# уренков,
# енков, Анатолий
# ков, Анатолий Ко
# , Анатолий Косты
# Анатолий Костырев

# %%
entity_spans
# Out:
# [(16, 20), (11, 12), (12, 16), (26, 27), (1, 3), (30, 32), (17, 17), (4, 7)]

# %%
samples
# Out:
# [Sample(text='Подобные расследования идут по всей Европе, самым громким за последние годы стал скандал вокруг Danske Bank — по мнению следствия, через его эстонское подразделение могли отмывать около €200 млрд.Яна Рождественская', span=(96, 107), ent='Danske Bank'),
#  Sample(text='В прошлом году другой местный финансовый конгломерат, ING, согласился выплатить €775 млн за прекращение дела об отмывании.', span=(54, 57), ent='ING'),
#  Sample(text='Власти Нидерландов начали расследование в отношении одного из крупнейших местных банков, ABN Amro, его подозревают в причастности к отмыванию денег.', span=(89, 97), ent='ABN Amro'),
#  Sample(text='Конкурсный управляющий полагает, что деньги были выведены из компании.Подробнее — в материале “Ъ” «Кредиторы "Вия" добрались до Китая».', span=(110, 113), ent='Вия'),
#  Sample(text='«Автокомплект» утверждал, что предоставил компании целевой заем на 30, 5 млн руб. на производство фильма «Вий 3D», который не был возвращен.', span=(1, 13), ent='Автокомплект'),
#  Sample(text='Продажа доли компании частным инвесторам должна была состояться в течение 2017–2019 годов, но этого так и не произошло.Подробнее о приватизации «Совкомфлота» читайте в публикации “Ъ”.', span=(145, 156), ent='Совкомфлота'),
#  Sample(text='К концу 2019 года необходимые сделки по разным причинам совершены не были.Ранее глава Минэкономики Максим Орешкин заявлял, что власти в закрытом режиме прорабатывают несколько сделок по приватизации, в том числе с зарубежными инвесторами.', span=(86, 98), ent='Минэкономики'),
#  Sample(text='В отличие от «Википедии», статьи нового российского энциклопедического сайта должны будут проходить научную проверку.', span=(14, 23), ent='Википедии')]

# %%
texts
# Out:
# ['В ноябре 2018 года суд признал компанию банкротом и открыл конкурсное производство.На сайте Palmali сообщается, что она основана в 2000 году.',
#  'Есть немного продуктов, которые приготовить можем только на костре", - цитируются также в сообщении слова капитана танкера Вадима Каючкина.Группа компаний Palmali, согласно информации на ее сайте, основана в Турции в 1998 году.',
#  'На все требования моряков вернуть их домой Palmali отвечает молчанием."По сути, компания просто бросила судно вместе с экипажем, никакой реакции ни на наши обращения, ни на сообщения моряков нет.',
#  'Сейчас прорабатываем технические вопросы", - сказал он.Трубопровод "Роснефти" Оха - Комсомольск-на-Амуре был перекрыт в июле после нефтеразлива близ Хабаровска на площади 0, 04 га.',
#  'Росприроднадзор оценил ущерб от происшествия в Норильске в рекордные 148, 2 млрд рублей.',
#  'Сейчас можно было переносить 100%, законопроект предлагает не более 50% на период 2021-2023 гг.Поправки к законопроекту принимаются профильным комитетом Госдумы до конца недели.',
#  'Для нефти, добываемой на участках второй группы, которые расположены в границах Ямальского района Ямало-Ненецкого автономного округа, на период с 1 января 2021 г. по 31 декабря 2023 г. составит 1, 95.По мнению аналитиков, под коэффициент 1, 95 подпадает Новопортовское месторождение "Газпром нефти", что ставит компанию в самое невыгодное положение среди других, для которых коэффициент составит 1, 2.Пересматривается процедура переноса исторических убытков.',
#  'INTERFAX.RU - Госдума приняла в первом чтении пакет законопроектов, который корректирует введенную в России с 1 января 2019 г. систему взимания налога на дополнительный доход (НДД), применяемого в основном в нефтяной отрасли.']
